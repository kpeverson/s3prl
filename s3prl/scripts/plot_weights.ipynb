# %%
# print heatmap for weights of three models

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /gscratch/tial/kpever/workspace/s3prl/s3prl/scripts/plot_weights.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Bklone-login/gscratch/tial/kpever/workspace/s3prl/s3prl/scripts/plot_weights.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell://ssh-remote%2Bklone-login/gscratch/tial/kpever/workspace/s3prl/s3prl/scripts/plot_weights.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import numpy as np
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bklone-login/gscratch/tial/kpever/workspace/s3prl/s3prl/scripts/plot_weights.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> import seaborn as sns
# ...

# %%
# weights are 13 dimensional vectors
speakervec_wts = torch.load('/gscratch/tial/kpever/workspace/s3prl/s3prl/result/downstream/speakervec_mlm_test/dev-best.ckpt', map_location='cpu')['Featurizer']['weights'].detach().numpy()
hubert_wts = torch.load('/gscratch/tial/kpever/workspace/s3prl/s3prl/result/downstream/test_v5/dev-best.ckpt', map_location='cpu')['Featurizer']['weights'].detach().numpy()
hubert_voxceleb_wts = torch.load('/gscratch/tial/kpever/workspace/s3prl/s3prl/result/downstream/speakervec_voxceleb1_hubert_test/dev-best.ckpt', map_location='cpu')['Featurizer']['weights'].detach().numpy()

# %%
# show heatmap for weights (3x13 plot)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /gscratch/tial/kpever/workspace/s3prl/s3prl/scripts/plot_weights.ipynb Cell 4 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2Bklone-login/gscratch/tial/kpever/workspace/s3prl/s3prl/scripts/plot_weights.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> plt.figure(figsize=(10, 10))
#       <a href='vscode-notebook-cell://ssh-remote%2Bklone-login/gscratch/tial/kpever/workspace/s3prl/s3prl/scripts/plot_weights.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> plt.subplot(131)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bklone-login/gscratch/tial/kpever/workspace/s3prl/s3prl/scripts/plot_weights.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> plt.imshow(hubert_wts.detach().numpy(), aspect='auto')
# ...
